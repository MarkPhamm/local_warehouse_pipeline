# %%
import duckdb
print("Connected!")
# Out:
# Connected!

# %%
import os
os.getcwd()
# Out:
# '/home/hoan/VSCode/projects/local_elt_pipeline/notebooks'

# %%
con = duckdb.connect("../database/cfpb_complaints.duckdb")
con

# %%
result = con.execute("SELECT catalog_name, schema_name FROM information_schema.schemata;").fetchdf()
result
# Out:
#       catalog_name         schema_name
# 0  cfpb_complaints        intermediate
# 1  cfpb_complaints                main
# 2  cfpb_complaints               marts
# 3  cfpb_complaints                 raw
# 4  cfpb_complaints         raw_staging
# 5  cfpb_complaints             staging
# 6           system  information_schema
# 7           system                main
# 8           system          pg_catalog
# 9             temp                main

# %% [markdown]
# ## So we just need to focus on catalog_nameL cfpb_complaints. Let explore everything on it

# %% [markdown]
# ### Raw -> raw_staging -> Staging -> Intermediate -> Marts
# 1. raw - Raw data exactly as loaded
# 2. raw_staging - Lightly cleaned + typed versions of raw
# 3. staging - Business-ready standardized tables
# 4. Intermediate - Transformations combining multiple staging models
# 5. marts - Final analytics tables for BI dashboards

# %% [markdown]
# # 1. Raw

# %%
# Show tables in the raw schema
raw_tables = con.sql("""
    SELECT table_name
    FROM information_schema.tables
    WHERE table_schema = 'raw'
    ORDER BY table_name;
""").df()
raw_tables
# Out:
#             table_name
# 0           _dlt_loads
# 1  _dlt_pipeline_state
# 2         _dlt_version
# 3      cfpb_complaints

# %%
# Explore each table
cfpb_complaints = con.sql("SELECT * FROM raw.cfpb_complaints LIMIT 3").df()
dlt_loads = con.sql("SELECT * FROM raw._dlt_loads LIMIT 3").df()
dlt_version = con.sql("SELECT * FROM raw._dlt_version LIMIT 3").df()
dlt_pipeline_state = con.sql("SELECT * FROM raw._dlt_pipeline_state LIMIT 3").df()

cfpb_complaints
# Out:
#                                              product complaint_what_happened  \
# 0  Credit reporting or other personal consumer re...
# 1                                        Credit card
# 2                                        Credit card
#
#        date_sent_to_company                                 issue  \
# 0 2025-11-05 12:00:00-05:00  Incorrect information on your report
# 1 2025-10-02 13:00:00-04:00  Incorrect information on your report
# 2 2024-09-03 13:00:00-04:00                 Getting a credit card
#
#                                   sub_product zip_code complaint_id timely  \
# 0                            Credit reporting    30501     17054567    Yes
# 1  General-purpose credit card or charge card    13021     16285565    Yes
# 2  General-purpose credit card or charge card    02631     10000688    Yes
#
#                   company_response submitted_via  ...  \
# 0                      In progress           Web  ...
# 1                      In progress           Web  ...
# 2  Closed with non-monetary relief   Postal mail  ...
#
#               date_received state consumer_disputed  \
# 0 2025-11-05 12:00:00-05:00    GA               N/A
# 1 2025-10-02 13:00:00-04:00    NY               N/A
# 2 2024-09-03 13:00:00-04:00    MA               N/A
#
#                                      sub_issue  \
# 0                     Account status incorrect
# 1          Information belongs to someone else
# 2  Card opened without my consent or knowledge
#
#                  _dlt_extracted_at        _dlt_load_id         _dlt_id  \
# 0 2025-11-29 20:41:26.161918-05:00  1764484856.0932565  teTjViH620pbXQ
# 1 2025-11-29 20:41:50.988020-05:00   1764484898.746703  DCm8e3jj9OzUOA
# 2 2025-12-04 15:00:26.649658-05:00    1764896401.92204  Ld/Hxv4D+ZxWwQ
#
#   consumer_consent_provided  tags company_public_response
# 0                      None  None                    None
# 1                      None  None                    None
# 2                       N/A  None                    None
#
# [3 rows x 21 columns]

# %%
con.sql("DESCRIBE raw.cfpb_complaints").df()
# Out:
#                   column_name               column_type null   key default  \
# 0                     product                   VARCHAR  YES  None    None
# 1     complaint_what_happened                   VARCHAR  YES  None    None
# 2        date_sent_to_company  TIMESTAMP WITH TIME ZONE  YES  None    None
# 3                       issue                   VARCHAR  YES  None    None
# 4                 sub_product                   VARCHAR  YES  None    None
# 5                    zip_code                   VARCHAR  YES  None    None
# 6                complaint_id                   VARCHAR   NO  None    None
# 7                      timely                   VARCHAR  YES  None    None
# 8            company_response                   VARCHAR  YES  None    None
# 9               submitted_via                   VARCHAR  YES  None    None
# 10                    company                   VARCHAR  YES  None    None
# 11              date_received  TIMESTAMP WITH TIME ZONE  YES  None    None
# 12                      state                   VARCHAR  YES  None    None
# 13          consumer_disputed                   VARCHAR  YES  None    None
# 14                  sub_issue                   VARCHAR  YES  None    None
# 15          _dlt_extracted_at  TIMESTAMP WITH TIME ZONE  YES  None    None
# 16               _dlt_load_id                   VARCHAR   NO  None    None
# 17                    _dlt_id                   VARCHAR   NO  None    None
# 18  consumer_consent_provided                   VARCHAR  YES  None    None
# 19                       tags                   VARCHAR  YES  None    None
# 20    company_public_response                   VARCHAR  YES  None    None
#
#    extra
# 0   None
# 1   None
# 2   None
# 3   None
# 4   None
# 5   None
# 6   None
# 7   None
# 8   None
# 9   None
# 10  None
# 11  None
# 12  None
# 13  None
# 14  None
# 15  None
# 16  None
# 17  None
# 18  None
# 19  None
# 20  None

# %%
# Count number of complaints for each company
con.sql("""
    SELECT company, COUNT(*) AS total
    FROM raw.cfpb_complaints
    GROUP BY company
    ORDER BY total DESC
""").df()
# Out:
#                                               company  total
# 0                   CAPITAL ONE FINANCIAL CORPORATION  68053
# 1                                JPMORGAN CHASE & CO.  56003
# 2                               WELLS FARGO & COMPANY  52658
# 3               BANK OF AMERICA, NATIONAL ASSOCIATION  45185
# 4                                      CITIBANK, N.A.  41131
# ..                                                ...    ...
# 63                                           UnBanked      2
# 64                     Secure One Capital Corporation      2
# 65  HUNTINGTON NATIONAL BANK, THE - FIRSTMERIT BAN...      1
# 66                                  TCF NATIONAL BANK      1
# 67                                Signature Bank (NY)      1
#
# [68 rows x 2 columns]

# %%
# FILTER OUT 10 COMPANIES
companies = [
    "CAPITAL ONE FINANCIAL CORPORATION",
    "JPMORGAN CHASE & CO.",
    "WELLS FARGO & COMPANY",
    "BANK OF AMERICA, NATIONAL ASSOCIATION",
    "CITIBANK, N.A.",
    "U.S. BANCORP",
    "GOLDMAN SACHS BANK USA",
    "PNC Bank N.A.",
    "TRUIST FINANCIAL CORPORATION",
    "STATE STREET BANK AND TRUST COMPANY"
]

query = f"""
    SELECT company, COUNT(*) AS total
    FROM raw.cfpb_complaints
    WHERE company IN ({','.join([f"'{c}'" for c in companies])})
    GROUP BY company
    ORDER BY total DESC
"""

con.sql(query).df()
# Out:
#                                  company  total
# 0      CAPITAL ONE FINANCIAL CORPORATION  68053
# 1                   JPMORGAN CHASE & CO.  56003
# 2                  WELLS FARGO & COMPANY  52658
# 3  BANK OF AMERICA, NATIONAL ASSOCIATION  45185
# 4                         CITIBANK, N.A.  41131
# 5                           U.S. BANCORP  13519
# 6                 GOLDMAN SACHS BANK USA  11972
# 7           TRUIST FINANCIAL CORPORATION  11936
# 8                          PNC Bank N.A.   7690
# 9    STATE STREET BANK AND TRUST COMPANY      8

# %% [markdown]
# ## Just keep 9 companies => Create a new table

# %%
companies = [
    "CAPITAL ONE FINANCIAL CORPORATION",
    "JPMORGAN CHASE & CO.",
    "WELLS FARGO & COMPANY",
    "BANK OF AMERICA, NATIONAL ASSOCIATION",
    "CITIBANK, N.A.",
    "U.S. BANCORP",
    "GOLDMAN SACHS BANK USA",
    "PNC Bank N.A.",
    "TRUIST FINANCIAL CORPORATION",
]

query = f"""
    CREATE OR REPLACE TABLE eda_complaints AS
    SELECT *
    FROM raw.cfpb_complaints
    WHERE company IN ({','.join([f"'{c}'" for c in companies])})
"""

con.sql(query)

# %%
con.close()
